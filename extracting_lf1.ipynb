# %%
from floodmodeller_api import LF1
import matplotlib.pyplot as plt

lf1 = LF1("GMMC_SH_BLN_13p0hr_0100yr_026.lf1")

lf1.convergence.plot()
#plt.savefig("convergence.png")
# Out:
# <Axes: xlabel='simulated'>

# %%
lf1.mass_error.plot()
#plt.savefig("mass_balance_error.png")
# Out:
# <Axes: xlabel='simulated'>

# %%
from pathlib import Path

from floodmodeller_api import LF1
import matplotlib.pyplot as plt



LOG_FILE = Path("sample.lf1")
CSV_OUT = LOG_FILE.with_name(f"{LOG_FILE.stem.upper()}_log.csv")

lf1 = LF1(LOG_FILE)
df = lf1.to_dataframe()
df.to_csv(CSV_OUT)
